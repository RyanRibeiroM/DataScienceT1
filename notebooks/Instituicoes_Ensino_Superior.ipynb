# %% [markdown]
# ### <center>Exploração De Dados Instituições De Ensino Superior Do Brasil</center>

# %% [markdown]
# Importando a biblioteca Pandas e verificando a natureza dos dados a primeira vista:

# %%
import pandas as pd

data = pd.read_csv("../data/raw/PDA_Lista_Instituicoes_Ensino_Superior_do_Brasil_EMEC.csv")

data
# Out:
#       CODIGO_DA_IES                                        NOME_DA_IES  \
# 0             21995             Faculdade de Tecnologia Senac Curitiba
# 1              1768                         FACULDADE REGIONAL SERRANA
# 2             23261       Faculdade São Judas de São Bernardo do Campo
# 3             14123  Faculdade Presidente Antônio Carlos de Bom Suc...
# 4             17952                 Faculdade de Tecnologia de Jacareí
# ...             ...                                                ...
# 4561          15792                              Faculdade de Rondônia
# 4562           1888                         FACULDADE DE SAÚDE TECSOMA
# 4563            925        FACULDADE DE CIÊNCIAS GERÊNCIAIS DE VILHENA
# 4564          22739                        Instituto SOCIESC de Itajaí
# 4565           5290  FACULDADE ANHANGUERA DE CIÊNCIAS E TECNOLOGIA ...
#
#                    SIGLA CATEGORIA_DA_IES COMUNITARIA CONFESSIONAL  \
# ...

# %% [markdown]
# Verificando quantos valores faltantes tem por atributo:

# %%
data.isna().sum()
# Out:
# CODIGO_DA_IES              0
# NOME_DA_IES                0
# SIGLA                    860
# CATEGORIA_DA_IES           0
# COMUNITARIA                0
# CONFESSIONAL               0
# FILANTROPICA               0
# ORGANIZACAO_ACADEMICA      0
# CODIGO_MUNICIPIO_IBGE    524
# MUNICIPIO                524
# UF                       524
# SITUACAO_IES               0
# dtype: int64

# %% [markdown]
# identificando quantas amostras e atributos existe no conjunto de dados:

# %%
print(f"O conjunto de dados possui {data.shape[0]} amostras e {data.shape[1]} atributos.")
# Out:
# O conjunto de dados possui 4566 amostras e 12 atributos.

# %% [markdown]
# Obtendo os atributos e os tipos de dados

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4566 entries, 0 to 4565
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CODIGO_DA_IES          4566 non-null   int64
#  1   NOME_DA_IES            4566 non-null   object
#  2   SIGLA                  3706 non-null   object
#  3   CATEGORIA_DA_IES       4566 non-null   object
#  4   COMUNITARIA            4566 non-null   object
#  5   CONFESSIONAL           4566 non-null   object
#  6   FILANTROPICA           4566 non-null   object
#  7   ORGANIZACAO_ACADEMICA  4566 non-null   object
#  8   CODIGO_MUNICIPIO_IBGE  4042 non-null   float64
#  9   MUNICIPIO              4042 non-null   object
#  10  UF                     4042 non-null   object
#  11  SITUACAO_IES           4566 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 428.2+ KB
