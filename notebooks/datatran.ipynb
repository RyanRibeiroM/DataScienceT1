# %% [markdown]
# ### <center>Exploração De Dados Datatran 2025</center>

# %% [markdown]
# Importando a biblioteca Pandas e verificando a natureza dos dados a primeira vista:

# %%
import pandas as pd

data = pd.read_csv("../data/raw/datatran2025.csv", encoding='latin-1', sep=';')

data.iloc[:, :15]
# Out:
#            id data_inversa     dia_semana   horario  uf   br     km  \
# 0      652493   2025-01-01   quarta-feira  06:20:00  SP  116    225
# 1      652519   2025-01-01   quarta-feira  07:50:00  CE  116  546,2
# 2      652522   2025-01-01   quarta-feira  08:45:00  PR  369   88,2
# 3      652544   2025-01-01   quarta-feira  11:00:00  PR  116     74
# 4      652549   2025-01-01   quarta-feira  09:30:00  MG  251    471
# ...       ...          ...            ...       ...  ..  ...    ...
# 47187  719592   2025-08-30         sábado  11:10:00  ES  101  295,6
# 47188  719614   2025-08-12    terça-feira  06:40:00  GO   40      6
# 47189  719649   2025-08-13   quarta-feira  19:00:00  SP  116    154
# 47190  719700   2025-08-30         sábado  15:05:00  BA  415     57
# 47191  719768   2025-07-14  segunda-feira  08:00:00  PB  230   22,7
#
#                    municipio  \
# 0                  GUARULHOS
# 1                  PENAFORTE
# 2          CORNELIO PROCOPIO
# 3      CAMPINA GRANDE DO SUL
# 4               FRANCISCO SA
# ...                      ...
# 47187              CARIACICA
# 47188    VALPARAISO DE GOIAS
# 47189    SAO JOSE DOS CAMPOS
# 47190                ITABUNA
# 47191            JOAO PESSOA
#
#                                           causa_acidente  \
# 0               Reação tardia ou ineficiente do condutor
# 1                                       Pista esburacada
# 2               Reação tardia ou ineficiente do condutor
# 3               Reação tardia ou ineficiente do condutor
# 4                                Velocidade Incompatível
# ...                                                  ...
# 47187           Objeto estático sobre o leito carroçável
# 47188  Condutor deixou de manter distância do veículo...
# 47189           Objeto estático sobre o leito carroçável
# 47190                     Ausência de reação do condutor
# 47191  Acessar a via sem observar a presença dos outr...
#
#                        tipo_acidente classificacao_acidente     fase_dia  \
# 0                         Tombamento    Com Vítimas Feridas    Pleno dia
# 1                    Colisão frontal                    NaN    Pleno dia
# 2                   Colisão traseira    Com Vítimas Feridas    Pleno dia
# 3          Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# 4                    Colisão frontal    Com Vítimas Feridas    Pleno dia
# ...                              ...                    ...          ...
# 47187                     Tombamento    Com Vítimas Feridas    Pleno dia
# 47188               Colisão traseira    Com Vítimas Feridas    Amanhecer
# 47189             Colisão com objeto    Com Vítimas Feridas  Plena Noite
# 47190      Saída de leito carroçável    Com Vítimas Feridas    Pleno dia
# 47191  Colisão lateral mesmo sentido    Com Vítimas Feridas    Pleno dia
#
#        sentido_via condicao_metereologica tipo_pista
# 0      Decrescente              Céu Claro   Múltipla
# 1        Crescente              Céu Claro    Simples
# 2        Crescente                    Sol      Dupla
# 3        Crescente              Céu Claro      Dupla
# 4      Decrescente                  Chuva    Simples
# ...            ...                    ...        ...
# 47187  Decrescente                Nublado      Dupla
# 47188  Decrescente               Ignorado      Dupla
# 47189  Decrescente               Ignorado      Dupla
# 47190  Decrescente              Céu Claro    Simples
# 47191  Decrescente                  Chuva      Dupla
#
# [47192 rows x 15 columns]

# %%
data["tracado_via"]
# Out:
# 0         Reta;Declive
# 1                 Reta
# 2          Reta;Aclive
# 3                 Reta
# 4        Curva;Declive
#              ...
# 47187             Reta
# 47188      Aclive;Reta
# 47189             Reta
# 47190            Curva
# 47191             Reta
# Name: tracado_via, Length: 47192, dtype: object

# %% [markdown]
# Verificando quantos valores faltantes tem por atributo:

# %%
data.isna().sum()
# Out:
# id                         0
# data_inversa               0
# dia_semana                 0
# horario                    0
# uf                         0
# br                         0
# km                         0
# municipio                  0
# causa_acidente             0
# tipo_acidente              0
# classificacao_acidente     1
# fase_dia                   0
# sentido_via                0
# condicao_metereologica     0
# tipo_pista                 0
# tracado_via                0
# uso_solo                   0
# pessoas                    0
# mortos                     0
# feridos_leves              0
# feridos_graves             0
# ilesos                     0
# ignorados                  0
# feridos                    0
# veiculos                   0
# latitude                   0
# longitude                  0
# regional                   1
# delegacia                 15
# uop                       22
# dtype: int64

# %% [markdown]
# identificando quantas amostras e atributos existe no conjunto de dados:

# %%
print(f"O conjunto de dados possui {data.shape[0]} amostras e {data.shape[1]} atributos.")
# Out:
# O conjunto de dados possui 47192 amostras e 30 atributos.

# %% [markdown]
# Obtendo os atributos e os tipos de dados:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47192 entries, 0 to 47191
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      47192 non-null  int64
#  1   data_inversa            47192 non-null  object
#  2   dia_semana              47192 non-null  object
#  3   horario                 47192 non-null  object
#  4   uf                      47192 non-null  object
#  5   br                      47192 non-null  int64
#  6   km                      47192 non-null  object
#  7   municipio               47192 non-null  object
#  8   causa_acidente          47192 non-null  object
#  9   tipo_acidente           47192 non-null  object
#  10  classificacao_acidente  47191 non-null  object
#  11  fase_dia                47192 non-null  object
#  12  sentido_via             47192 non-null  object
#  13  condicao_metereologica  47192 non-null  object
#  14  tipo_pista              47192 non-null  object
#  15  tracado_via             47192 non-null  object
#  16  uso_solo                47192 non-null  object
#  17  pessoas                 47192 non-null  int64
#  18  mortos                  47192 non-null  int64
#  19  feridos_leves           47192 non-null  int64
#  20  feridos_graves          47192 non-null  int64
#  21  ilesos                  47192 non-null  int64
#  22  ignorados               47192 non-null  int64
#  23  feridos                 47192 non-null  int64
#  24  veiculos                47192 non-null  int64
#  25  latitude                47192 non-null  object
#  26  longitude               47192 non-null  object
#  27  regional                47191 non-null  object
#  28  delegacia               47177 non-null  object
#  29  uop                     47170 non-null  object
# dtypes: int64(10), object(20)
# memory usage: 10.8+ MB
